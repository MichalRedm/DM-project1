# %% [markdown]
# # Code samples

# %% [markdown]
# First, we'll import all the necessary libraries and functions that we have implemented.

# %%
import pandas as pd
from preprocess import preprocess

# %% [markdown]
# To illustrate how our preprocessing works, let's import the dataset that we are using in our experiment.

# %%
df = pd.read_csv("CarsData.csv")
df.head()
# Out:
#            model  year  price transmission  mileage fuelType  tax   mpg  \
# 0            I10  2017   7495       Manual    11630   Petrol  145  60.1
# 1           Polo  2017  10989       Manual     9200   Petrol  145  58.9
# 2       2 Series  2019  27990    Semi-Auto     1614   Diesel  145  49.6
# 3   Yeti Outdoor  2017  12495       Manual    30960   Diesel  150  62.8
# 4         Fiesta  2017   7999       Manual    19353   Petrol  125  54.3
#
#    engineSize Manufacturer
# 0         1.0       hyundi
# 1         1.0   volkswagen
# 2         2.0          BMW
# 3         2.0        skoda
# 4         1.2         ford

# %% [markdown]
# Let us see what is the effect of our function `preprocess`, used for transforming the data.

# %%
preprocess(df, target="price").head()
# Out:
#    componenet0  componenet1  componenet2  componenet3  componenet4  \
# 0    -0.061325     1.086454    -0.837091     0.603295     0.262565
# 1    -0.150470     1.128804    -0.862481     0.475072     0.295706
# 2    -1.581833    -0.123695     0.960080    -0.099154     0.239616
# 3     0.168580    -0.551741     0.395775     0.607504    -0.581399
# 4     0.092386     0.741502    -0.837758     0.169809    -0.049627
#
#    componenet5  componenet6  componenet7  componenet8  componenet9  ...  \
# 0     0.117377     0.128906    -0.016715     0.109262     0.067967  ...
# 1     0.027867     0.665889     0.829599    -0.006955    -0.097599  ...
# 2    -0.220379    -0.185822     0.069912    -0.061182     0.918685  ...
# 3     0.443354     0.092376     0.097957     0.202668     0.032486  ...
# 4     0.276358    -0.579975     0.089769    -0.276826    -0.127186  ...
#
#    componenet21  componenet22  componenet23  componenet24  componenet25  \
# 0     -0.038346     -0.049106     -0.145031     -0.043586      0.154055
# 1     -0.318651     -0.061590      0.088273      0.020066     -0.048955
# 2     -0.105118     -0.013767      0.024417      0.035767      0.224899
# 3      0.036848      0.035288      0.152585      0.031328     -0.032995
# 4     -0.008308     -0.005567     -0.039285     -0.006276      0.005925
#
#    componenet26  componenet27  componenet28  componenet29  price
# 0     -0.048407      0.046650     -0.006822      0.019938   7495
# 1      0.014696     -0.004634      0.018283     -0.005759  10989
# 2      0.550826     -0.302162      0.057180      0.146501  27990
# 3      0.013367     -0.010180      0.013057     -0.023202  12495
# 4     -0.001399     -0.006205     -0.004326      0.010764   7999
#
# [5 rows x 31 columns]

# %% [markdown]
# We can try to tweak a few parameters. For example, instead of using the default feature extraction method, which is PCA (Principal Component Analysis) we can use LDA (Linear Discriminant Analysis):

# %%
preprocess(df, target="price", feature_extraction_method="LDA").head()
# Out:
#    componenet0  componenet1  componenet2  componenet3  componenet4  \
# 0     4.078430     1.162027    -0.620544     0.102534     0.624363
# 1     1.804505    -0.997714     0.431322    -0.346480    -0.089322
# 2    -3.670387    -1.827402    -0.329004     1.221570     0.351202
# 3     0.130875    -0.026030     0.256254     0.424460    -0.655940
# 4     1.881615     0.048389     0.319601    -0.420374     0.046675
#
#    componenet5  componenet6  componenet7  componenet8  componenet9  ...  \
# 0     0.044283     1.633284    -0.180133     1.154254     0.868012  ...
# 1     0.032255    -0.463499    -0.119391    -0.574145    -0.558497  ...
# 2     0.478909    -0.673353    -0.708843     1.712731    -0.420790  ...
# 3     0.050720    -0.307550     0.064457    -0.004407    -0.731562  ...
# 4    -0.050191    -0.178517     0.094389    -0.241788     0.112766  ...
#
#    componenet21  componenet22  componenet23  componenet24  componenet25  \
# 0      0.564748      0.187560      0.194428     -2.021290     -2.442746
# 1     -0.066888      0.156256      0.070424      0.485914      0.500733
# 2     -0.126226      0.141754      0.304181      0.017803      0.297379
# 3      0.280038     -0.615872     -0.233987     -0.332073      0.025178
# 4     -0.325335      0.263164      0.571403      0.884114     -0.320290
#
#    componenet26  componenet27  componenet28  componenet29  price
# 0     -2.180037      0.082778      1.700415     -1.713080   7495
# 1      0.813873     -1.690842      1.631866     -0.392219  10989
# 2     -0.134972     -0.272485      0.097241     -0.564140  27990
# 3      0.386584     -0.141617      1.099880      0.699752  12495
# 4     -0.539746     -0.525142     -0.429076     -0.284876   7999
#
# [5 rows x 31 columns]

# %% [markdown]
# Let us increase the value of `feature_selection_treshold`. This will significantly change the result.

# %%
preprocess(df, target="price", feature_selection_treshold=1000.0).head()
# Out:
#    componenet0  componenet1  componenet2  componenet3  componenet4  \
# 0    -0.581332    -1.299914     0.303025     0.031935     0.106172
# 1    -0.670748    -1.311547     0.314985     0.113871     0.602877
# 2    -1.203972     1.143320     0.001088    -0.060262     0.192244
# 3     0.436375     0.511731    -0.383083     0.522358     0.247546
# 4    -0.263704    -0.976091     0.112261     0.078665    -0.061263
#
#    componenet5  componenet6  componenet7  componenet8  componenet9  ...  \
# 0     0.105150    -0.214675     0.057518    -0.354522    -0.153743  ...
# 1    -0.785689     0.311405    -0.060477     0.069074    -0.220555  ...
# 2     0.078558    -0.736494    -0.696950     0.102396    -0.100952  ...
# 3     0.178580    -0.065219     0.072253    -0.249238     0.125777  ...
# 4     0.011513    -0.058756     0.058622    -0.245612    -0.132717  ...
#
#    componenet21  componenet22  componenet23  componenet24  componenet25  \
# 0      0.000942      0.006710      0.031886      0.021367      0.130373
# 1      0.052477      0.127650      0.001709     -0.016905     -0.018741
# 2      0.058516     -0.015828      0.084734      0.060644      0.321746
# 3      0.000432     -0.014065     -0.011866     -0.048772     -0.100861
# 4     -0.015842     -0.005316      0.029608     -0.042162     -0.099058
#
#    componenet26  componenet27  componenet28  componenet29  price
# 0      0.102298      0.095423      0.586160      0.323849   7495
# 1     -0.007202     -0.001215      0.001708      0.000887  10989
# 2     -0.519186      0.012012      0.011036     -0.030893  27990
# 3     -0.052490     -0.022055      0.007355      0.063711  12495
# 4     -0.030049     -0.016012      0.002782      0.015006   7999
#
# [5 rows x 31 columns]

# %% [markdown]
# Increasing the value of parameter `variance_treshold` will have a similar effect:

# %%
preprocess(df, target="price", variance_treshold=0.015).head()
# Out:
#    componenet0  componenet1  componenet2  componenet3  componenet4  \
# 0    -0.143548    -1.198300    -0.788327     0.640172     0.139673
# 1    -0.232835    -1.247112    -0.814956     0.517659     0.133067
# 2    -1.504676     0.343720     1.123544    -0.108554     0.117965
# 3     0.241407     0.655107     0.514542     0.616875    -0.677277
# 4     0.009866    -0.853828    -0.820067     0.166179     0.041509
#
#    componenet5  componenet6  componenet7  componenet8  componenet9  ...  \
# 0     0.227581     0.160091    -0.066428    -0.097149    -0.212016  ...
# 1     0.209221     0.392469     0.921462     0.185419     0.035166  ...
# 2    -0.153771     0.439086    -0.120747    -0.755351     0.459142  ...
# 3     0.443237     0.018986    -0.017203     0.015192    -0.129056  ...
# 4     0.108878    -0.087663    -0.066869    -0.052325    -0.295070  ...
#
#    componenet21  componenet22  componenet23  componenet24  componenet25  \
# 0      0.031296     -0.045051     -0.126061     -0.023619      0.000647
# 1     -0.325824     -0.168750      0.063896      0.018472      0.020985
# 2     -0.073567     -0.040086      0.025919      0.047930      0.006452
# 3      0.013639      0.004926      0.162672      0.032276      0.014184
# 4     -0.048290     -0.027451     -0.044159      0.006841      0.004902
#
#    componenet26  componenet27  componenet28  componenet29  price
# 0     -0.012043     -0.001093     -0.022724     -0.012200   7495
# 1      0.018411      0.009309     -0.105912      0.070864  10989
# 2     -0.010052     -0.274613     -0.069985     -0.027925  27990
# 3     -0.034926     -0.024312      0.121076      0.073346  12495
# 4      0.019265      0.012734     -0.029552     -0.018492   7999
#
# [5 rows x 31 columns]

# %% [markdown]
# To modify the number of components, we can change the parameter `n_components`.

# %%
preprocess(df, target="price", n_components=15).head()
# Out:
#    componenet0  componenet1  componenet2  componenet3  componenet4  \
# 0    -0.061325     1.086454    -0.837091     0.603295     0.262565
# 1    -0.150470     1.128804    -0.862481     0.475072     0.295706
# 2    -1.581833    -0.123695     0.960080    -0.099154     0.239616
# 3     0.168580    -0.551741     0.395775     0.607504    -0.581399
# 4     0.092386     0.741502    -0.837758     0.169809    -0.049627
#
#    componenet5  componenet6  componenet7  componenet8  componenet9  \
# 0     0.117377     0.128906    -0.016715     0.109266     0.067968
# 1     0.027867     0.665889     0.829599    -0.006950    -0.097600
# 2    -0.220379    -0.185821     0.069914    -0.061188     0.918694
# 3     0.443354     0.092376     0.097957     0.202666     0.032487
# 4     0.276358    -0.579975     0.089769    -0.276827    -0.127185
#
#    componenet10  componenet11  componenet12  componenet13  componenet14  price
# 0      0.151676     -0.467263      0.321976      0.198460      1.046320   7495
# 1      0.006466     -0.081819      0.261713     -0.130927     -0.153120  10989
# 2     -0.431352     -0.325708      0.070697      0.121014     -0.130621  27990
# 3      0.108166     -0.152247      0.018935      0.217054      0.032130  12495
# 4     -0.093093      0.125193      0.073583     -0.009118     -0.024887   7999
